# %%
from connec_functions import execute_to_df, generate_sparql

# %% [markdown]
# ## Data system users

# %%
datasys_users = execute_to_df("organization.sparql")

# %%
#overview summary
datasys_users.describe()
# Out:
#                                                      user  \
# count                                                2827
# unique                                               2827
# top     http://lifewatch-user-analysis-2023/user/97930...
# freq                                                    1
#
#                            affiliation  country  \
# count                             1084     1084
# unique                             229       45
# top     VLIZ Flanders Marine Institute  Belgium
# freq                               127      420
#
#                                              group  \
# count                                         1084
# unique                                          19
# top     http://lifewatch.org/ns/Research_institute
# freq                                           436
#
#                                      qh
# count                              1084
# unique                                4
# top     http://lifewatch.org/ns/Science
# freq                                963

# %%
# horizontal barplot of affiliation country count, from datasystem users
dsusers_per_country_fig = datasys_users['country'].value_counts().plot.barh(
    title = "Datasystem users",
    ylabel="country", 
    xlabel="user count")

# %%
# table of unique datasystem users grouped per type of affiliation and quadruple helix group  
datasys_users.groupby(['qh','group']).nunique()
# Out:
#                                                                                         user  \
# qh                                    group
# http://lifewatch.org/ns/Civil_society http://lifewatch.org/ns/Creative_body                2
#                                       http://lifewatch.org/ns/NGO                          2
#                                       http://lifewatch.org/ns/Non-profit_organization     21
#                                       http://lifewatch.org/ns/Other                        4
# http://lifewatch.org/ns/Industry      http://lifewatch.org/ns/Company                     23
#                                       http://lifewatch.org/ns/Consultancy                 11
# http://lifewatch.org/ns/Policy        http://lifewatch.org/ns/Defence                      2
#                                       http://lifewatch.org/ns/EU_institution               5
#                                       http://lifewatch.org/ns/Governmental_body           49
#                                       http://lifewatch.org/ns/Intergovernmental_body       1
#                                       http://lifewatch.org/ns/Other_public_authorities     1
# http://lifewatch.org/ns/Science       http://lifewatch.org/ns/Data_infrastructure         10
#                                       http://lifewatch.org/ns/International_programme     12
#                                       http://lifewatch.org/ns/Museum                      96
#                                       http://lifewatch.org/ns/Research_                    3
#                                       http://lifewatch.org/ns/Research_Institute           2
#                                       http://lifewatch.org/ns/Research_institute         436
#                                       http://lifewatch.org/ns/Research_network             1
#                                       http://lifewatch.org/ns/University                 403
#
#                                                                                         affiliation  \
# qh                                    group
# http://lifewatch.org/ns/Civil_society http://lifewatch.org/ns/Creative_body                       2
#                                       http://lifewatch.org/ns/NGO                                 1
#                                       http://lifewatch.org/ns/Non-profit_organization             8
#                                       http://lifewatch.org/ns/Other                               2
# http://lifewatch.org/ns/Industry      http://lifewatch.org/ns/Company                            15
#                                       http://lifewatch.org/ns/Consultancy                         7
# http://lifewatch.org/ns/Policy        http://lifewatch.org/ns/Defence                             1
#                                       http://lifewatch.org/ns/EU_institution                      1
#                                       http://lifewatch.org/ns/Governmental_body                  20
#                                       http://lifewatch.org/ns/Intergovernmental_body              1
#                                       http://lifewatch.org/ns/Other_public_authorities            1
# http://lifewatch.org/ns/Science       http://lifewatch.org/ns/Data_infrastructure                 3
#                                       http://lifewatch.org/ns/International_programme             2
#                                       http://lifewatch.org/ns/Museum                             16
#                                       http://lifewatch.org/ns/Research_                           1
#                                       http://lifewatch.org/ns/Research_Institute                  1
#                                       http://lifewatch.org/ns/Research_institute                 49
#                                       http://lifewatch.org/ns/Research_network                    1
#                                       http://lifewatch.org/ns/University                         97
#
#                                                                                         country
# qh                                    group
# http://lifewatch.org/ns/Civil_society http://lifewatch.org/ns/Creative_body                   2
#                                       http://lifewatch.org/ns/NGO                             1
#                                       http://lifewatch.org/ns/Non-profit_organization         5
#                                       http://lifewatch.org/ns/Other                           2
# http://lifewatch.org/ns/Industry      http://lifewatch.org/ns/Company                         8
#                                       http://lifewatch.org/ns/Consultancy                     5
# http://lifewatch.org/ns/Policy        http://lifewatch.org/ns/Defence                         1
#                                       http://lifewatch.org/ns/EU_institution                  1
#                                       http://lifewatch.org/ns/Governmental_body              10
#                                       http://lifewatch.org/ns/Intergovernmental_body          1
#                                       http://lifewatch.org/ns/Other_public_authorities        1
# http://lifewatch.org/ns/Science       http://lifewatch.org/ns/Data_infrastructure             3
#                                       http://lifewatch.org/ns/International_programme         2
#                                       http://lifewatch.org/ns/Museum                         10
#                                       http://lifewatch.org/ns/Research_                       1
#                                       http://lifewatch.org/ns/Research_Institute              1
#                                       http://lifewatch.org/ns/Research_institute             25
#                                       http://lifewatch.org/ns/Research_network                1
#                                       http://lifewatch.org/ns/University                     33

# %% [markdown]
# ## Publications

# %% [markdown]
# ### Number of publications

# %%
publications = execute_to_df("publication.sparql")

# %%
# overview summary of LW publications (publications stored in on of the 13 LW special collections)
publications.describe()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 2
#       1 # overview summary of LW publications (publications stored in on of the 13 LW special collections)
# ----> 2 publications.describe()
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/generic.py:11970, in NDFrame.describe(self, percentiles, include, exclude)
#   11728 @final
#   11729 def describe(
#   11730     self,
#    (...)
#   11733     exclude=None,
#   11734 ) -> Self:
#   11735     """
#   11736     Generate descriptive statistics.
#   11737
#    (...)
#   11968     max            NaN      3.0
#   11969     """
# > 11970     return describe_ndframe(
#   11971         obj=self,
#   11972         include=include,
#   11973         exclude=exclude,
#   11974         percentiles=percentiles,
#   11975     ).__finalize__(self, method="describe")
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/methods/describe.py:91, in describe_ndframe(obj, include, exclude, percentiles)
#      87     describer = SeriesDescriber(
#      88         obj=cast("Series", obj),
#      89     )
#      90 else:
# ---> 91     describer = DataFrameDescriber(
#      92         obj=cast("DataFrame", obj),
#      93         include=include,
#      94         exclude=exclude,
#      95     )
#      97 result = describer.describe(percentiles=percentiles)
#      98 return cast(NDFrameT, result)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/methods/describe.py:162, in DataFrameDescriber.__init__(self, obj, include, exclude)
#     159 self.exclude = exclude
#     161 if obj.ndim == 2 and obj.columns.size == 0:
# --> 162     raise ValueError("Cannot describe a DataFrame without columns")
#     164 super().__init__(obj)
#
# ValueError: Cannot describe a DataFrame without columns

# %%
# table number of publications per year & cummulative number of publications per year


# histogram graph of number of publications per year


# histogram graph of cummulative number of publications per year

# %% [markdown]
# ### First author affiliations

# %%
# horizontal histogram graph of number of publications per country 


# table of first author affiliations per quadruple helix category

# %% [markdown]
# ### Relevance to Sustainable Development Goals (SDG's)

# %%
execute_to_df("organization.sparql")
# Out:
#                                                 project  \
# 0     genid-11606ef13bc348e28a7356769e270cd820-E9991...
# 1     genid-11606ef13bc348e28a7356769e270cd820-55CDE...
# 2     genid-11606ef13bc348e28a7356769e270cd820-F7B5C...
# 3     genid-11606ef13bc348e28a7356769e270cd820-77484...
# 4     genid-11606ef13bc348e28a7356769e270cd820-CF8B0...
# ...                                                 ...
# 2822  genid-11606ef13bc348e28a7356769e270cd844-6F1F5...
# 2823  genid-11606ef13bc348e28a7356769e270cd844-6906C...
# 2824  genid-11606ef13bc348e28a7356769e270cd844-EE380...
# 2825  genid-11606ef13bc348e28a7356769e270cd844-65DB4...
# 2826  genid-11606ef13bc348e28a7356769e270cd844-E4161...
#
#                                                name
# 0                    VLIZ Flanders Marine Institute
# 1                                Hasselt University
# 2                                  Ghent University
# 3     INBO Research Institute for Nature and Forest
# 4            Wageningen University & Research (WUR)
# ...                                             ...
# 2822                                            NaN
# 2823                                            NaN
# 2824                                            NaN
# 2825                                            NaN
# 2826                                            NaN
#
# [2827 rows x 2 columns]
